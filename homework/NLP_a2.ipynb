# %% [markdown]
# # DIGS 20006/30006 : NLP Assignment 2

# %%
import nltk
from nltk.book import *
from nltk.corpus import words
from nltk.corpus import wordnet
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def unusual_words(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab - english_vocab
    return sorted(unusual)

def unusual_words_many(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    manywords = nltk.corpus.words.words() + list(nltk.corpus.wordnet.words())
    english_vocab = set(w.lower() for w in manywords)
    unusual = text_vocab - english_vocab
    return sorted(unusual)

def unusual_words_many_no_endings_s_ed_ing(text):
    ut1 = unusual_words(text)
    print(str(len(ut1))+" words not in words.words\n")
    ut2 = unusual_words_many(text)
    print(str(len(ut2))+" words not in words.words + wordnet.words\n")
    ut3 = sorted(set(w.lower() for w in ut2 if not w.endswith("s") and not w.endswith("ed") and not w.endswith("ing")))
    print(str(len(ut3))+" words not in words.words + wordnet.words + no -s, -ed and -ing :\n")
    print(ut3)
    # -en plurals, -er and -est still not uncommon

# %% [markdown]
# ## Q1

# %% [markdown]
# I have chosen 'The Count of Monte Cristo' By Alexandre Dumas and cause it is my favourite western novel. I only limited pre-processing (taking out the contents and the footnotes) since the text I downloaded from gutenberg.org was pretty clean.

# %%
with open("MC.txt") as f:
    content = f.read().splitlines()
    #content = list(filter(None, content))
    raw = " ".join(content)
    text = [word.lower() for word in raw.split() ]
    text = [word.rstrip() for word in text]

# %%
text[:10]
# Out:
# ['chapter',
#  '1.',
#  'marseilles—the',
#  'arrival',
#  'on',
#  'the',
#  '24th',
#  'of',
#  'february,',
#  '1815,']

# %%
len(text)
# Out:
# 460025

# %% [markdown]
# ## Q2

# %%
print("The raw length of my text is %d" % len(text))
# Out:
# The raw length of my text is 460025

# %% [markdown]
# ## Q3

# %%
print("The number of tokens in my text is %d" % len(set(text)))
# Out:
# The number of tokens in my text is 38076

# %% [markdown]
# ## Q4

# %%
def lex_score(t):
    return len(set(t))/len(t)

print("The lexical diversity score of my text is %f" % lex_score(text))
# Out:
# The lexical diversity score of my text is 0.082769

# %% [markdown]
# The lexical diversity score of text2 'Sense and Sensibility' is 0.048263, while the lexical diversity score of 'The Count of Monte Cristo' is 0.082769. It appears that Alexandre Dumas' use of tokens is almost twice as rich as Jane Austen. My speculation is that those two authors are from different countries and have different genders. Also, 'The Count of Monte Cristo' is originally written in French, my text used the English version of it. I am not sure whether the translation affects the lexical diversity.

# %% [markdown]
# ## Q5 Remove all punctuation

# %%
import re
clean =[]
for s in text:
    s = re.sub(r'[^\w\s\d]',' ',s) 
    s = s.rstrip()
    s = s.lstrip()
    clean.append(s)

# %%
clean[:10]
# Out:
# ['chapter',
#  '1',
#  'marseilles the',
#  'arrival',
#  'on',
#  'the',
#  '24th',
#  'of',
#  'february',
#  '1815']

# %%
print("The raw length of my text without punctuation is %d" % len(clean))
print("The number of tokens in my text without punctuation is %d" % len(set(clean)))
print("The lexical diversity score of my text without punctuation is %f" % lex_score(clean))
# Out:
# The raw length of my text without punctuation is 460025
# The number of tokens in my text without punctuation is 19391
# The lexical diversity score of my text without punctuation is 0.042152

# %% [markdown]
# ## Q6 Remove stopwords

# %%
stopwords = nltk.corpus.stopwords.words('english')
nonstop = [word for word in clean if word not in stopwords]

# %%
print("The raw length of my text without stopwords is %d" % len(nonstop))
print("The number of tokens in my text without stopwords is %d" % len(set(nonstop)))
print("The lexical diversity score of my text without stopwords is %f" % lex_score(nonstop))
# Out:
# The raw length of my text without stopwords is 220468
# The number of tokens in my text without stopwords is 19258
# The lexical diversity score of my text without stopwords is 0.087351

# %% [markdown]
# ## Q7 Comparisons

# %% [markdown]
# Removing all the punctuation and stopwords decreased the length of the text and the number of tokens in the text greatly. What I felt interesting is after removing punctuation, the lexical diversity score decreased from 0.0827 to 0.065; However, the lexical diversity score increased to 0.1221 after removing stopwords. The stopwords count greatly as the raw length but not unique tokens.

# %% [markdown]
# ## Q8 Words with lengths greater than 12 letters

# %%
LongWords = [word.rstrip() for word in nonstop if len(word.rstrip())>12]
LongWords = set(LongWords)

# %%
LongWords
# Out:
# {'dressing room i',
#  'fortune first rate',
#  'fontenay aux roses',
#  'infallibility',
#  'boat  two  three',
#  'inconvenienced',
#  'hassen ben sabah',
#  'parliamentary',
#  'benefactor the',
#  'condescending',
#  'pocket handkerchief',
#  'advantage  that',
#  'everyone many',
#  'well informed',
#  'appearance we',
#  'calculating by',
#  'manufacturing',
#  'villefort see',
#  'chimney piece',
#  'congestion nothing',
#  'death because',
#  'lemonade that s',
#  'half official',
#  'stiff  having',
#  'excellency  said',
#  'mother in law s',
#  'evinced  none',
#  'wedding present',
#  'julie emmanuel',
#  'double barreled',
#  'philanthropist',
#  'majestic that',
#  'unconsciousness',
#  'superstitious',
#  'valentine  permit',
#  'notwithstanding',
#  'mourning coaches',
#  'alphabets one',
#  'corridors instead',
#  'countess nothing',
#  'occurred what',
#  'unaccountable',
#  'shepherdesses',
#  'floor polisher',
#  'cypress trees',
#  'whithersoever',
#  'millionaire his',
#  'd avrigny  her',
#  'grief stricken',
#  'half supporting',
#  'all   giovanni',
#  'inconceivable',
#  'shameful  must',
#  'agriculturists',
#  'hackney coachmen',
#  'imperturbable',
#  'incredulously',
#  'usurpers cromwell',
#  'above nothing',
#  'weapons  which',
#  'tailor probably',
#  'recollection my',
#  'what  what  the',
#  'flower stands',
#  'mischief    that s',
#  'knee breeches',
#  'you perfectly',
#  'hackney coach',
#  'speaking  besides',
#  'time remember',
#  'required smelling bottles',
#  'gloomy looking',
#  'assistance  shall',
#  'robespierre s',
#  'world everything',
#  'three fourths',
#  'breakfast hour',
#  'conflagration',
#  'simultaneously',
#  'energy  marseilles',
#  'unlimited nothing',
#  'garnet colored',
#  'distinguished',
#  'spectators romans',
#  'travelling thanks',
#  'assistance he',
#  'winding sheet  a',
#  'ineffectually',
#  'determination',
#  'plucked twelve',
#  'participation',
#  'door keeper s',
#  'understand  air',
#  'misfortunes  someone',
#  'procureur general',
#  'superstitions',
#  'fellow countryman',
#  'servants  you',
#  'extinguishing',
#  'visiting cards',
#  'intermarrying',
#  'entertainments',
#  'beautiful always',
#  'practitioners',
#  'carriage wheels',
#  'meritorious  it',
#  'understand you',
#  'assassinations',
#  'expressionless',
#  'clermont ferrand',
#  'philanthropic',
#  'peaceful shall',
#  'worse diavolo',
#  'inoffensively',
#  'visits  designed',
#  'misfortune alone',
#  'communicate yes',
#  'proceedings    he',
#  'interrogatories',
#  'reminiscences',
#  'fortunes emmanuel',
#  'mortefontaine',
#  'attention  it',
#  'house impossible',
#  'waiting  today',
#  'nothing after',
#  'vice president',
#  'proceeding if',
#  'sledge hammer',
#  'sorts  titles',
#  'understanding',
#  'imperceptibly',
#  'virtues don t',
#  'you  noirtier',
#  'distinguishable',
#  'principalities',
#  'waist girdles',
#  'mediterranean  marseilles',
#  'landing place',
#  'disembarrassed',
#  'corsica complained',
#  'strangers the',
#  'prison  seventeen',
#  'poisoned    i',
#  'champ de mars',
#  'half suffocated',
#  'grudgingly  an',
#  'fellow sufferer',
#  'marvellous  that',
#  'good extended',
#  'letter  sinbad',
#  'slave merchant',
#  'uncertainties  wretched',
#  'bayonets madmen',
#  'indisposition',
#  'suffer through',
#  'unadulterated',
#  'caderousse he',
#  'swift flitting',
#  'condescension',
#  'conclusion  that',
#  'catastrophes  were',
#  'night then even',
#  'above mentioned',
#  'mortemart  took',
#  'monstrosities',
#  'disadvantageous',
#  'irreproachable',
#  'praiseworthy  nay',
#  'misfortunes  it',
#  'introductions',
#  'chimney corner',
#  'exterminating',
#  'before making',
#  'weariness for',
#  'remedies time',
#  'footsteps they',
#  'unequivocally',
#  'relinquishing',
#  'unhesitatingly',
#  'correspondent s',
#  'billiard table',
#  'court martialed',
#  'unaccompanied',
#  'announcements',
#  'saint méran  a',
#  'calculations i',
#  'child   hold if',
#  'advertisements',
#  'brother in law',
#  'self dependence',
#  'providence it',
#  'posting master',
#  'circumstances',
#  'precipitation',
#  'tortoise shell',
#  'watering pots',
#  'viscount  the',
#  'banking house',
#  'case precisely',
#  'saint méran s',
#  'significantly',
#  'provinces  my',
#  'english eminent',
#  'unconsciously',
#  'carriage lamps',
#  'slaughterhouse',
#  'hallucination',
#  'single sticks for',
#  'four and twenty pound',
#  'christmas boxes',
#  'attentively if',
#  'five and twenty',
#  'slave merchants',
#  'scrutinizingly',
#  'wanting  having',
#  'affectionately',
#  'gentlemen  some',
#  'inauspiciously',
#  'yes  yesterday',
#  'meaning  therefore',
#  'morrel because',
#  'endorsement of',
#  'extraordinary',
#  'bertuccio you',
#  'question   nothing',
#  'entrance gate',
#  'vulture shaped',
#  'departments i',
#  'half fainting',
#  'disappointment',
#  'sycamore tree',
#  'château renaud s',
#  'halting places',
#  'controversies',
#  'gardener  ate',
#  'circumlocution',
#  'advertisement',
#  'witness    yes',
#  'sickly looking',
#  'remained poor',
#  'wretched wretched',
#  'treasure seekers',
#  'ruined  completely',
#  'acknowledging',
#  'harshness  for',
#  'prisoners liberty',
#  'mourning coach',
#  'qualification',
#  'counterfeited',
#  'see saturday i',
#  'communicating',
#  'grandfather  that',
#  'characterized',
#  'contributions',
#  'traheret wait',
#  'it  maximilian  has',
#  'pixérécourt  27',
#  'villefort  yes',
#  'mondego    indeed',
#  'breakfast parlor',
#  'aix la chapelle',
#  'industriously',
#  'this  thomson',
#  'blood stained',
#  'misunderstood',
#  'stammered  edward',
#  'saint philippe du roule',
#  'expression never',
#  'double locking',
#  'disappear that',
#  'blood thirsty',
#  'pilate washing',
#  'villefort  wake',
#  'all powerful he',
#  'instinct  and',
#  'yes  christian',
#  'inhabited the',
#  'silence night',
#  'selfishness it',
#  'self destruction',
#  'you misfortunes',
#  'winding sheet',
#  'valet de chambre',
#  'demonstrations',
#  'saint mandrier',
#  'constantinople',
#  'single handed',
#  'cookery which',
#  'correspondence',
#  'brute accustomed',
#  'unworthy that',
#  'waiting women',
#  'discouragement',
#  'something something',
#  'eight and forty',
#  'today because',
#  'revolutionists',
#  'circumstantial',
#  'tremulousness',
#  'arrangement something',
#  'independently',
#  'sententiously',
#  'progressively',
#  'carriage drive',
#  'good tempered',
#  'petersburg calm',
#  'disturbance all',
#  'over everything',
#  'suspended   to',
#  'horror stricken',
#  'trieste penelon',
#  'starting post',
#  'understand  of',
#  'blocked  reverend',
#  'impossibilities',
#  'cannon that s',
#  'mesdemoiselles',
#  'fontaine saint georges',
#  'susceptibility',
#  'moccoletti franz',
#  'four and twenty',
#  'irrepressible',
#  'travelling cap',
#  'three quarters',
#  'extinguishers',
#  'administrator',
#  'mountain  theories',
#  'punch drenched',
#  'mercédès they',
#  'fellow creature',
#  'jack o  lanterns',
#  'dressing case',
#  'somewhere away',
#  'narrow brimmed',
#  'violet colored',
#  'everything you',
#  'valentine valentine you',
#  'marriage  have',
#  'octagonal shaped',
#  'misunderstand',
#  'reception room',
#  'saint bernard',
#  'grandchildren',
#  'cause services',
#  'murmured   yes',
#  'gesticulating',
#  'assassin some',
#  'poisoned  you',
#  'propensities these',
#  'unintelligible',
#  'rousseau  you',
#  'untouched    my',
#  'saint jean aux bois',
#  'mother in law',
#  'sleeping room',
#  'granddaughter',
#  'remorselessly',
#  'scupper holes',
#  'well disciplined',
#  'parisians  that',
#  'instinctively',
#  'recommendation',
#  'imagination a',
#  'impossibilium',
#  'mademoiselle s',
#  'violence  well',
#  'organization a',
#  'prepossessing',
#  'myrtle bushes',
#  'preliminaries',
#  'sluggish have',
#  'indifferently',
#  'comprehend we',
#  'uncontrollable',
#  'energetically',
#  'inflexible he',
#  'refuge  refuse',
#  'asmodeus that',
#  'excellency  there',
#  'elsewhere have',
#  'danglars that',
#  'musicians you',
#  'millionaire  once',
#  'ridiculous stupid',
#  'accomplices one',
#  'indeed indeed',
#  'dressing room',
#  'bellegarde  a',
#  'contemptuously',
#  'philosophy  it',
#  'languages  was',
#  'dramatic explain',
#  'cristo   here',
#  'maximilian they',
#  'never to be forgotten',
#  'conversations',
#  'sentimentality',
#  'aigues mortes',
#  'cristo  precisely',
#  'moment  which',
#  'lieutenant général',
#  'whom  how  of',
#  'all pervasive',
#  'gastro enteritis',
#  'white bellied',
#  'dressing gown',
#  'formalities the',
#  'disappearance',
#  'preparation  sounds',
#  'high principled',
#  'step daughter',
#  'mother of pearl',
#  'treasure seeker',
#  'considerations',
#  'shakespeare s',
#  'unceremonious',
#  'breakfast room',
#  'certainly certainly',
#  'betrothed mademoiselle',
#  'foster mother',
#  'music everything',
#  'circumstances i',
#  'perhaps perhaps',
#  'conscience  and',
#  'sergeant at arms',
#  'understand no',
#  'confidence resolved',
#  'conspiracy  tis',
#  'concealed amidst',
#  'society would',
#  'field marshal',
#  'heir presumptive',
#  'insensibility',
#  'chimney board',
#  'marseilles come',
#  'self confidence',
#  'masters warranted',
#  'self possessed',
#  'punishment  all',
#  'multiplication',
#  'incongruously',
#  'entertainment',
#  'villefort  what',
#  'broad brimmed',
#  'him sometimes',
#  'indiscriminately',
#  'saint sulpice',
#  'well organized',
#  'fellow creatures',
#  'discovered at',
#  'whisper intimating',
#  'lives someone',
#  'constantinian',
#  'thirty six pound',
#  'improbability',
#  'mathematician',
#  'schoolfellow  a',
#  'accomplishment',
#  'rather rather',
#  'albert  morrel who',
#  'justification',
#  'without   mercédès',
#  'high spirited',
#  'emotion   sir',
#  'prisons  that',
#  'parbleu  they',
#  'hunting horns',
#  'streets people',
#  'themselves  for',
#  'reconstructed',
#  'mortification',
#  'unintentional',
#  'five and twenty he',
#  'substance  in',
#  'quick sighted',
#  'guilty  there',
#  'asserted    alas',
#  'straightforward',
#  'enthusiastically',
#  'indispensable',
#  'three and thirty',
#  'speech  which',
#  'granddaughter s',
#  'one and twenty',
#  'understood  and',
#  'free perfectly',
#  'half kindness',
#  'knife grinder',
#  'cavalcanti of',
#  'personification',
#  'tapestry such',
#  'committee room',
#  'feeling   believe',
#  'transformation',
#  'marriage portion',
#  'south south west',
#  'burial ground',
#  'visiting room',
#  'sentiments  i',
#  'business like',
#  'market gardeners',
#  'produced from',
#  'satisfaction tell',
#  'sufficient where',
#  'misunderstanding',
#  'receiver general',
#  'mother country',
#  'fellow admirably',
#  'rospigliosi s',
#  'encouragingly',
#  'then  finding',
#  'haroun al raschids',
#  'administering',
#  'problematical',
#  'inexperienced',
#  'portmanteau let',
#  'noirtier  try',
#  'proportionate',
#  'recollections',
#  'chamberlain in waiting',
#  'unprecedented',
#  'dealings take',
#  'diametrically',
#  'statue   yielding',
#  'self satisfaction',
#  'captain himself',
#  'simple looking',
#  'disinterested',
#  'inconvenience',
#  'bird of paradise',
#  'congratulations',
#  'carriage  faith',
#  'studding sails',
#  'representatives',
#  'hallucinations',
#  'grand marshal',
#  'performing  a',
#  'companionship',
#  'predominating',
#  'incomprehensible',
#  'enthusiasm all',
#  'gratification',
#  'uneasiness corsica',
#  'possibilities',
#  'maximilian   madame',
#  'smugglers but',
#  'civita castellana',
#  'certificate that',
#  'dissimilarity',
#  'provisions he',
#  'ambition  fernand',
#  'inconceivably',
#  'two and twenty  he',
#  'gendarmes all',
#  'saint germain des',
#  'recrimination',
#  'thanks thanks',
#  'porto vecchio',
#  'secret service',
#  'phlegmatically',
#  'superintendence',
#  'never failing',
#  'curious  what',
#  'months dantès',
#  'father in law',
#  'indefatigable',
#  'office holders',
#  'apoplexy that',
#  'heard cavalcanti',
#  'jurisprudence',
#  'saint gothard',
#  'rhododendrons',
#  'six and twenty',
#  'said   god god',
#  'terrible that',
#  'diplomatically that',
#  'monsieur  you',
#  'inspector general',
#  'revolutions m',
#  'viceroyalties',
#  'years  fourteen',
#  'unnecessarily',
#  'grandmother s',
#  'view  marseilles',
#  'anyone  pardon',
#  'seven and twenty',
#  'nobleman  young',
#  'consideration',
#  'madame  thanks',
#  'paris amongst',
#  'smelling bottle',
#  'considerately',
#  'congratulated',
#  'philosophically',
#  'rule eccentric',
#  'unsophisticated',
#  'disembarkment',
#  'three cornered',
#  'uncomfortable',
#  'grand marshal s',
#  'contrary  that',
#  'health hurrah',
#  'strong minded',
#  'indiscretion  oh',
#  'inconsiderable',
#  'impossible  utterly',
#  'transaction  i',
#  'providence all',
#  'passed seventy two',
#  'chastity modesty innocence',
#  'met at ah yes',
#  'husband  well',
#  'uninteresting',
#  'probabilities',
#  'fellow countrymen',
#  'responsibility',
#  'mediterranean',
#  'pastrini   utterly',
#  'pont de beauvoisin',
#  'interrogating',
#  'calm   danglars',
#  'accumulations',
#  'unexceptionable',
#  'drawing rooms',
#  'posting house',
#  'contains give',
#  'banking houses',
#  'characteristic',
#  'heiress valentine',
#  'hunting knife',
#  'individuals a',
#  'adversaries i',
#  'indescribable',
#  'conventionalist',
#  'double barrelled',
#  'handkerchiefs',
#  'not   content',
#  'two and thirty',
#  'half dilapidated',
#  'improprieties',
#  'superintending',
#  'albert  while',
#  'acquaintances and',
#  'saint dominique',
#  'peculiarity  they',
#  'porto ferrajo',
#  '600 000 700 000 800 000 900 000',
#  'coachman   rue',
#  'poniards twenty',
#  'mistaken maximilian',
#  'clover fields',
#  'incapacity ineptitude',
#  'mizzen topsails',
#  'transportation',
#  'morcerfs  stay',
#  'waiting place',
#  'country house',
#  'inopportunely',
#  'remember  the',
#  'clenched   say',
#  'me listen and',
#  'correggio was',
#  'hungry  that s',
#  'involuntarily',
#  'stock jobbing',
#  'imagine   and',
#  'choreographic',
#  'ill concealed',
#  'caderousse you',
#  'insurmountable',
#  'benefit  therefore',
#  'september that',
#  'well executed',
#  'suffices begone',
#  'relationships',
#  'benefactor then',
#  'everything kiosk',
#  'mother  capital',
#  'paving stones',
#  'fowling piece',
#  'capital  yes i',
#  'opportunities',
#  'assembly room',
#  'which precursors',
#  'fencing master',
#  'maximilian  there',
#  'kitchen garden',
#  'conversing the',
#  'carriage door',
#  'course complete',
#  'open and stay',
#  'half expiring',
#  'acquaintance  two',
#  'juxtaposition',
#  'villefort  observe',
#  'd aguesseau 11',
#  'well regulated',
#  'revealing  tell',
#  'battle fields',
#  'doubtless becomes',
#  'pedestal that',
#  'position both',
#  'supernaturally',
#  'high buttoned',
#  'corroborative',
#  'grandpapa ah m',
#  'thoroughfares',
#  'countersigned',
#  'ministrations',
#  'apprehensions',
#  'accumulate let',
#  'moment  terror',
#  'harbor master',
#  'punishment that',
#  'blindfolded you',
#  'terror stricken',
#  'interruptions',
#  'blunderbusses',
#  'manifestation',
#  'treasures unless',
#  'ever blooming',
#  'danglars   it',
#  'letters  five and twenty',
#  'unceremoniously',
#  'gone positively',
#  'deglutition a',
#  'act  remember',
#  'unjust shamefully',
#  'interpretation',
#  'pre engagement',
#  'pocket mirror',
#  'accomplishing',
#  'compassionate',
#  'arm   valentine',
#  'minds mercédès',
#  'grandfather s',
#  'undoubtedly  at',
#  'imperceptible',
#  'emissaries  one',
#  'servant that s',
#  'half carrying',
#  'aladdin judge',
#  'doubtless  at',
#  'saint méran and',
#  'silence unbroken',
#  're established',
#  'unexceptional',
#  'noirtier   do',
#  'contemplation',
#  'notre dame du mont carmel',
#  'employed  faria',
#  'denunciations',
#  'chestnut trees',
#  'saint laurent',
#  'will yes  let',
#  'anticipations',
#  'establishment',
#  'albert  sorrow',
#  'travellers indeed',
#  'equipages  dazzling',
#  'continued   yes',
#  'white striped',
#  'sub lieutenant',
#  'apartments  for',
#  'letter  donned',
#  'villefort  villefort',
#  'contradictory',
#  'guillotine  we',
#  'wife mademoiselle',
#  'fishing vessel',
#  'french arrives',
#  'fidelity this',
#  'condolences  which',
#  'misadventures',
#  'condottieri  for',
#  'princess  will',
#  'recollections an',
#  'tomorrow  that',
#  'knowledge  and',
#  'riding horses',
#  'exclaimed   forgive',
#  'ill temperedly',
#  'galley slaves',
#  'all sufficient',
#  'sailors  songs',
#  'unresistingly',
#  'snuff box  scarcely',
#  'haitians  that',
#  'half ferocious',
#  'marriage contract',
#  'explain where',
#  'thoughts what',
#  'marseilles    yes',
#  'flame colored',
#  'recommendations',
#  'moments never',
#  'contrary what',
#  'horticulturist',
#  'foster father',
#  'chefs d œuvre',
#  'double paused',
#  'panther skins',
#  'governor general',
#  'pleasure boat',
#  'millions  three  four',
#  'disappointments',
#  'villefort  you',
#  'dwelling place',
#  'authoritative',
#  'nightmare that s',
#  'villefort   in',
#  'flower garden',
#  'gardener penelon',
#  'required namely',
#  'say valentine',
#  'communications',
#  'highly colored',
#  'forgetfulness',
#  'maximilian emmanuel if',
#  'comfortable eh',
#  'breast pocket  yes',
#  'executioner s',
#  'brother in law s',
#  'bonapartism i',
#  'stay  stay  how',
#  'superfluities',
#  'compassionately',
#  'reply   close',
#  'phrenological',
#  'things  indeed',
#  'girondin  noirtier',
#  'consternation',
#  'objection the',
#  'unwillingness',
#  'never varying',
#  'accommodation',
#  'quartermaster',
#  'lemonade sellers',
#  'acknowledgement',
#  'recollect  danglars',
#  'potentialities',
#  'theirs before',
#  'clear sighted',
#  'moderation  but',
#  'consciousness',
#  'disinterred no',
#  'presentiments',
#  'awe inspiring',
#  'danglars excuse',
#  'convulsively  adieu',
#  'customs officer',
#  'emmanuel julie farewell',
#  'conversation permit',
#  'père lachaise',
#  'villefort  charming',
#  'lieutenant colonel',
#  'subterraneous',
#  'steward  thus',
#  'cherry laurel',
#  'understand everyone',
#  'marksman there',
#  'felicitations',
#  'fortune   upon',
#  'voluptuousness',
#  'police office',
#  'conscientious',
#  'wicked looking',
#  'duty    selim',
#  'unintentionally',
#  'countenance neither',
#  'hiding places',
#  'orange flowers',
#  'perhaps pleasing',
#  'strange looking',
#  'found nothing',
#  'commiseration',
#  'sustained nothing',
#  'supernumerary',
#  'extremity nay',
#  'boxing gloves',
#  'floral decked',
#  'advantageously',
#  'self examination',
#  'nothing absolutely',
#  'differed  the',
#  'château renaud m',
#  'ramifications',
#  'tranquillizing',
#  'impossibility',
#  'precipitation this',
#  'superiority in',
#  'louis jacques',
#  'comprehending',
#  'illuminations',
#  'disproportion',
#  'everything  those',
#  'revolutionary',
#  'phosphorescent',
#  'candidly  something',
#  'valentine  that',
#  'knitting needle',
#  'serious minded',
#  'listening what',
#  'attorneys general',
#  'interrogative',
#  'himself half malicious',
#  'established that',
#  'ideality  these',
#  'corroboration',
#  'ill concealing',
#  'philosophical',
#  'fortune brilliant',
#  'supplications',
#  'obsequiousness',
#  'vengeance nothing',
#  'richelieu for',
#  'effort   today',
#  'letter perhaps',
#  'inconsiderate',
#  'saint jacques',
#  'remembers and',
#  'scruple  that',
#  'misfortune  the',
#  'duel  calculated',
#  'state councillor',
#  'acknowledgments',
#  'innocence  it',
#  'beauchamp visit',
#  'representative',
#  'weather beaten',
#  'distinguishing',
#  'napoleon well',
#  'sister in law',
#  'perfectly   did',
#  'dangerous  and',
#  'investigation',
#  'tepelini    if',
#  'reproach  you',
#  'sea side what',
#  'added   still',
#  'metamorphosis',
#  'disdain  these',
#  'constitutional',
#  'double locked',
#  'acquaintances',
#  'false besides',
#  'apricots they',
#  'miscellaneous',
#  'encouragement',
#  'moment napoleon',
#  'prisoners   anyone',
#  'beautiful  if',
#  'disorders  then',
#  'signatures  since',
#  'curiosity that',
#  'mischievously',
#  'embarrassment',
#  'correspondent',
#  'aristocracy the',
#  'corresponding',
#  'islands daume',
#  'master stroke',
#  'contemplating',
#  'indifferences',
#  'self preservation',
#  'deeply regretted',
#  'adventures you',
#  'daughter in law',
#  'shooting gallery',
#  'dantès  instructions',
#  'contrary  you',
#  'no everything',
#  'transteverins',
#  'disapprobation',
#  'château renaud',
#  'existence  you',
#  'wedding dress',
#  'chapelle en serval',
#  'correspondents',
#  'demonstration',
#  'tragedy going',
#  'single hearted',
#  'costumes gigantic',
#  'intelligible   home',
#  'yard  eugénie',
#  'blood colored',
#  'provocation  in',
#  'mercédès  then',
#  'multiplication table',
#  'unprepossessing',
#  'wedding  never',
#  'understood is',
#  'vessel certainly',
#  'circumstances   gentlemen',
#  'yes there is a postscript',
#  'two and twenty',
#  'champs élysées',
#  'constitutionnel',
#  'comparatively',
#  ...}

# %% [markdown]
# ## Q9 Unusual Words

# %%
unusual = unusual_words_many_no_endings_s_ed_ing(nonstop)
# Out:
# 5328 words not in words.words
#
# 4373 words not in words.words + wordnet.words
#
# 833 words not in words.words + wordnet.words + no -s, -ed and -ing :
#
# ['abbé', 'abruzzo', 'abélard', 'académie', 'actæon', 'adelmonte', 'admirari', 'affettatore', 'aguado', 'alatri', 'albanese', 'albano', 'aleria', 'alicante', 'alla', 'allée', 'almo', 'amasine', 'amwaiter', 'amélie', 'anagni', 'anglo', 'anguille', 'anhelitu', 'anse', 'antoine', 'appert', 'appian', 'aquapendente', 'aquilo', 'aquit', 'archæology', 'arcola', 'ariosto', 'arlesian', 'arlesienne', 'arma', 'arstein', 'assafœtida', 'assunta', 'athalie', 'auguste', 'auteuil', 'avi', 'avrà', 'azzo', 'babuino', 'bajocco', 'baldi', 'banquo', 'baptiste', 'baptistin', 'barbare', 'barberi', 'baronne', 'barrière', 'bartolomeo', 'bartoloni', 'bassora', 'bastia', 'beaucaire', 'beauchamp', 'beaurepaire', 'beauveau', 'beauvoisin', 'became', 'bedeau', 'befallen', 'befell', 'began', 'bellegarde', 'bellevue', 'benedetto', 'bentivoglio', 'beppo', 'bertuccio', 'betaken', 'bidassoa', 'bidden', 'bitterest', 'blanchet', 'blasé', 'blew', 'blin', 'blount', 'boileau', 'boiteux', 'boldest', 'bonifacio', 'borgo', 'bossuet', 'bouc', 'bouillotte', 'boulanger', 'boulogne', 'bourget', 'bourmont', 'boville', 'boyador', 'bracciano', 'bravest', 'bravi', 'brezé', 'brighter', 'brightest', 'britzka', 'brucea', 'brunhilda', 'bréguet', 'busoni', 'bussy', 'béranger', 'caderousse', 'café', 'caisserie', 'calasareigne', 'calaseraigne', 'cama', 'camargue', 'canebière', 'cangiar', 'canst', 'capisco', 'caprara', 'capua', 'caracalla', 'carbonaro', 'carceri', 'carconte', 'carlini', 'casa', 'cascine', 'castellana', 'catalane', 'cattini', 'cavalcante', 'cavalcanti', 'cedant', 'centigramme', 'cervetri', 'cessato', 'chambre', 'chambéry', 'chandernagor', 'changarnier', 'chantilly', 'charenton', 'chargé', 'chaussée', 'chibouque', 'children', 'choicest', 'christi', 'churchmen', 'château', 'châteauroux', 'châtillon', 'cito', 'citorio', 'civita', 'ck', 'claudo', 'clearest', 'cleverest', 'coachmen', 'coarsest', 'colomba', 'colosseo', 'comedia', 'commodo', 'commonest', 'compagno', 'compiègne', 'comtesse', 'conciergerie', 'condé', 'consigne', 'constitutionnel', 'contadina', 'contadini', 'contino', 'cornélie', 'corsaire', 'corsinari', 'corso', 'corte', 'cosa', 'coselli', 'couldst', 'countrymen', 'countrywomen', 'coupé', 'cristo', 'croiselle', 'cucumetto', 'curé', 'cæsar', 'césar', 'dandré', 'darker', 'darkest', 'daume', 'dauphiné', 'deadliest', 'dearer', 'debray', 'decapitato', 'deeper', 'deepest', 'dei', 'deianira', 'deidamia', 'delaunay', 'delle', 'delvino', 'demoustier', 'deniseau', 'dentro', 'deo', 'desdemona', 'devedeux', 'devoret', 'diable', 'diavolaccio', 'diavolo', 'didier', 'dieppe', 'dieu', 'direst', 'divina', 'domum', 'dorante', 'dormice', 'dost', 'douane', 'douw', 'dr', 'drapeau', 'drollest', 'du', 'dubuquoi', 'duc', 'duchampy', 'duchâtel', 'duguesclin', 'duprez', 'dupré', 'durand', 'dyck', 'dædalian', 'ecco', 'elba', 'elssler', 'enghien', 'englishwomen', 'entrée', 'eo', 'errare', 'et', 'etc', 'eugénie', 'fac', 'facchini', 'facchino', 'faintest', 'faria', 'fattore', 'fatui', 'faustina', 'fayette', 'feet', 'fenestrelle', 'fenzi', 'ferentino', 'fernand', 'ferrajo', 'ferrea', 'ferrusino', 'festa', 'fiano', 'fiercer', 'fiesole', 'finest', 'firma', 'fishermen', 'fisherwomen', 'flamel', 'flandre', 'flavien', 'florentin', 'foi', 'fondest', 'fondi', 'fontaine', 'fontainebleau', 'fontana', 'footmen', 'foresaw', 'foreseen', 'forgiven', 'forsook', 'franca', 'francesca', 'francesi', 'franz', 'frascati', 'frattina', 'fredegund', 'frenchmen', 'frioul', 'frosinone', 'fullest', 'fusaro', 'fécamp', 'férou', 'fête', 'gabri', 'gaetano', 'gard', 'garde', 'garigliano', 'gaslamp', 'gaspard', 'gasparone', 'gaumard', 'gayest', 'gayety', 'gaëta', 'gaîté', 'gentlemen', 'gentler', 'germain', 'giacomo', 'giannutri', 'giglio', 'giraud', 'giveth', 'glossiest', 'goodnight', 'gorgone', 'gracchi', 'graffan', 'grandchildren', 'grandmamma', 'grandpapa', 'graphein', 'gravest', 'gregorio', 'grisi', 'grisier', 'grève', 'grétry', 'guiche', 'gutteral', 'guzerat', 'guzla', 'guénégaud', 'gérard', 'hague', 'hallo', 'handsome ...

# %% [markdown]
# There are lots of French words are listed. It makes sense since this novel is originally written in French and I am using an English version of it to do the analysis. Some comparalatives and superlatives also appeared, like "wider, wildest, wisest"

# %% [markdown]
# ## Q10 Most Common Words

# %%
print(FreqDist(nonstop).most_common(50))
# Out:
# [('said', 3474), ('one', 1447), ('count', 1354), ('man', 1299), ('would', 1205), ('monte', 1131), ('cristo', 1091), ('de', 1028), ('villefort', 988), ('yes', 942), ('well', 939), ('danglars', 906), ('know', 834), ('young', 793), ('two', 766), ('madame', 760), ('morrel', 747), ('replied', 738), ('albert', 729), ('see', 727), ('dantès', 723), ('time', 719), ('like', 685), ('could', 639), ('shall', 603), ('made', 592), ('sir', 589), ('say', 586), ('valentine', 585), ('must', 575), ('father', 570), ('oh', 569), ('franz', 551), ('us', 539), ('come', 533), ('first', 531), ('door', 522), ('may', 514), ('upon', 508), ('eyes', 506), ('hand', 504), ('without', 495), ('house', 494), ('tell', 465), ('asked', 462), ('much', 461), ('day', 458), ('never', 431), ('old', 429), ('still', 422)]

# %% [markdown]
# The results are not very surprising. Monte Cristo (Dantès) appeared very frequently. The other characters' names Danglars, Villefort, Valentine and Morrel appeared quite frequently. "never" and "still" indicated the Monte Cristo's determination to revenge.

# %% [markdown]
# ## Q11 Compare to Jane Austen

# %%
nonstop2 = [word for word in text2 if word.isalnum() and (word not in stopwords)]
print(FreqDist(nonstop2).most_common(50))
# Out:
# [('I', 2004), ('Elinor', 684), ('could', 568), ('Marianne', 566), ('Mrs', 530), ('would', 507), ('said', 397), ('every', 361), ('one', 304), ('But', 289), ('much', 287), ('sister', 282), ('must', 279), ('Edward', 262), ('mother', 258), ('She', 258), ('Dashwood', 252), ('The', 243), ('time', 237), ('know', 230), ('Jennings', 230), ('might', 215), ('Willoughby', 215), ('think', 209), ('Miss', 208), ('though', 204), ('He', 203), ('well', 191), ('It', 189), ('thing', 185), ('Lucy', 185), ('never', 184), ('soon', 180), ('Mr', 178), ('see', 173), ('Colonel', 173), ('without', 171), ('nothing', 170), ('ever', 169), ('may', 169), ('good', 166), ('John', 163), ('first', 160), ('say', 160), ('house', 159), ('little', 158), ('day', 150), ('great', 149), ('two', 145), ('however', 145)]

# %% [markdown]
# I haven't read 'Sense and Sensibility' by Jane Austen, but from the title and the most common word of the book. My guess is that this book is a romance novel, it may has a happy ending. While 'The Count of Monte Cristo' has a more gloomy theme. And I felt if I run machine learning on this two text, the authors' gender can be predicted correctly.
